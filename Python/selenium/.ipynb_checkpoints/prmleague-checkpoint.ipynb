# %%
from selenium import webdriver
import requests
from bs4 import BeautifulSoup

def getprmleague():

    driver = webdriver.Chrome("C:/Users/dohan/chromedriver.exe")
    driver.get("https://www.premierleague.com/tables")

    df = pd.DataFrame(columns=["Position", "Club", "Played", "Won", "Drawn", "Lost", "GF", "GA", "GD", "Points", "Next"])
    
    prmtable_selector = driver.find_elements_by_css_selector("#mainContent .tableBodyContainer")[0]
    for i in range(1, 40, 2):
        items = prmtable_selector.find_elements_by_css_selector("tr:nth-child(%d)" % i)

        for item in items:
            Position = item.find_element_by_css_selector('td:nth-child(2)').text
            Club = item.find_element_by_css_selector("td:nth-child(3)").text
            Played = item.find_element_by_css_selector("td:nth-child(4)").text
            Won = item.find_element_by_css_selector("td:nth-child(5)").text
            Drawn = item.find_element_by_css_selector("td:nth-child(6)").text
            Lost = item.find_element_by_css_selector("td:nth-child(7)").text
            GF = item.find_element_by_css_selector("td:nth-child(8)").text
            GA = item.find_element_by_css_selector("td:nth-child(9)").text
            GD = item.find_element_by_css_selector("td:nth-child(10)").text
            Points = item.find_element_by_css_selector("td:nth-child(11)").text
#             Form = item.find_element_by_css_selector('td:nth-child(12) #Tooltip a:nth-child(1)').get_attribute('href')
            Next = item.find_element_by_css_selector("td:nth-child(13) #Tooltip a").get_attribute('href')
            data = {"Position": Position,
                   "Club": Club,
                   "Played": Played,
                   "Won": Won,
                   "Drawn": Drawn,
                   "Lost": Lost,
                   "GF": GF,
                   "GA": GA,
                   "GD": GD,
                   "Points": Points,
                   "Next": Next}

        df.loc[len(df)] = data

    driver.close()
    return df

result = getprmleague()
result
# Out:
#    Position                      Club Played Won Drawn Lost  GF  GA   GD  \
# 0         1           Manchester City     27  23     3    1  79  20  +59
# 1         2         Manchester United     28  18     5    5  53  20  +33
# 2         3                 Liverpool     28  16     9    3  65  32  +33
# 3         4         Tottenham Hotspur     28  16     7    5  53  24  +29
# 4         5                   Chelsea     28  16     5    7  50  25  +25
# 5         6                   Arsenal     27  13     6    8  51  36  +15
# 6         7                   Burnley     28   9    10    9  22  25   -3
# 7         8            Leicester City     28   9     9   10  40  41   -1
# 8         9                   Everton     28   9     7   12  32  47  -15
# 9        10                   Watford     28   9     6   13  38  47   -9
# 10       11               Bournemouth     28   8     8   12  33  43  -10
# 11       12  Brighton and Hove Albion     28   7    10   11  26  37  -11
# ...
